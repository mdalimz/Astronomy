# %%
# Importing library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import ascii
from astropy.io import fits

# %%
#Getting the sdss data from fits file
spectra = fits.open('C:/Users/mdram/astroML_data/SDSSspec/1615/spSpec-53166-1615-513.fit')
#FITS (Flexible Image Transport System) is a portable file standard widely used in the astronomy community to store images and tables.

# %%
# Data at a glance
spectra.info()
# Out:
# Filename: C:/Users/mdram/astroML_data/SDSSspec/1615/spSpec-53166-1615-513.fit
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     224   (3856, 5)   float32
#   1                1 BinTableHDU     54   6R x 23C   [1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1J, 1E, 1E, 1E, 1E, 1A]
#   2                1 BinTableHDU     54   44R x 23C   [1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1J, 1E, 1E, 1E, 1E, 1A]
#   3                1 BinTableHDU     18   1R x 5C   [1E, 1E, 1E, 1J, 1E]
#   4                1 BinTableHDU     32   53R x 12C   [1J, 1J, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]
#   5                1 BinTableHDU     26   36R x 9C   [19A, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]
#   6                1 BinTableHDU     14   3856R x 3C   [1J, 1J, 1E]

# %% [markdown]
# Every Header Data Unit (HDU) normally has two components: header and data. In astropy these two components are accessed through the two attributes of the HDU, hdu.header and hdu.data.

# %% [markdown]
# The terms you mentioned are common in FITS (Flexible Image Transport System) data files, which are widely used in astronomy for storing, transmitting, and analyzing scientific data. Here’s a brief explanation of each term:
#
# No.: This likely refers to the number or index of the data entry.
# Name: The name or identifier of the data entry.
# Ver: The version of the data or software used.
# Type: The type of data or object (e.g., image, table).
# Cards: This refers to the number of header cards in the FITS file. Each card contains metadata about the data.
# Dimensions: The dimensions of the data array (e.g., 2D image, 3D data cube).
# Format: The format of the data (e.g., integer, floating-point).

# %%
data=spectra[1].data
data
# Out:
# FITS_rec([(3805.9844, 0.45251465, 3799.2686, 3814.1697, 5.266804 , 0.49333286, 0.5, -9999., 39.251595, 2.6065521, 106.33526, 4.8731775, 0.4592786 , 2., -9999.,  1.1007695e+00, 37.15278 , 17,    0.   , 1.3563156e-19, -9.999000e+03, -9999., ''),
#           (3831.7537, 0.8017578 , 3827.366 , 3847.6895, 5.0621095, 0.55308247, 0.5, -9999., 22.629276, 2.1214943, 112.58713, 2.5503423, 0.28793508, 2., -9999.,  1.2403005e+00, 91.995224, 23,    0.   , 1.3563156e-19, -9.999000e+03, -9999., ''),
#           (4115.9814, 0.7998047 , 4108.658 , 4122.8735, 4.3557806, 1.0536268 , 0.5, -9999., 19.699144, 3.1164665, 167.56004, 1.2835947, 0.2890325 , 2., -9999.,  1.3584152e+00, 49.642235, 14,    0.   , 1.3563156e-19, -9.999000e+03, -9999., ''),
#           (5325.853 , 0.5488281 , 5321.0825, 5330.8936, 2.7284248, 0.4682449 , 0.5, -9999., 19.229145, 2.9669971, 248.30046, 0.5296384, 0.        , 2., -9999.,  1.1636003e+00,  5.479234,  7,    0.   , 1.3563156e-19, -9.999000e+03, -9999., ''),
# ...

# %%
hdr=spectra[1].header
hdr
# Out:
# XTENSION= 'BINTABLE'
# BITPIX  =                    8
# NAXIS   =                    2
# NAXIS1  =                   89
# NAXIS2  =                    6
# PCOUNT  =                    0
# GCOUNT  =                    1
# TFIELDS =                   23
# TFORM1  = '1E      '
# TTYPE1  = 'wave    '
# TFORM2  = '1E      '
# TTYPE2  = 'waveErr '
# TFORM3  = '1E      '
# TTYPE3  = 'waveMin '
# TFORM4  = '1E      '
# TTYPE4  = 'waveMax '
# TFORM5  = '1E      '
# TTYPE5  = 'sigma   '
# TFORM6  = '1E      '
# TTYPE6  = 'sigmaErr'
# TFORM7  = '1E      '
# TTYPE7  = 'sigmaMin'
# TFORM8  = '1E      '
# TTYPE8  = 'sigmaMax'
# TFORM9  = '1E      '
# TTYPE9  = 'height  '
# TFORM10 = '1E      '
# TTYPE10 = 'heightErr'
# TFORM11 = '1E      '
# TTYPE11 = 'continuum'
# TFORM12 = '1E      '
# TTYPE12 = 'ew      '
# TFORM13 = '1E      '
# TTYPE13 = 'ewErr   '
# TFORM14 = '1E      '
# TTYPE14 = 'ewMin   '
# TFORM15 = '1E      '
# TTYPE15 = 'specIndex'
# TFORM16 = '1E      '
# TTYPE16 = 'nsigma  '
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\astropy\io\fits\column.py in _get_index(names, key)
#    2036         try:
# -> 2037             indx = names.index(key.rstrip())
#    2038         except ValueError:
#
# ValueError: '1E' is not in list
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-99108549a700> in <module>
# ----> 1 wave=data['1E']
#       2 wave
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\fitsrec.py in __getitem__(self, key)
#     505
#     506         if isinstance(key, str):
# --> 507             return self.field(key)
#     508
#     509         # Have to view as a recarray then back as a FITS_rec, otherwise the
#
# ~\anaconda3\lib\site-packages\astropy\io\fits\fitsrec.py in field(self, key)
# ...

# %%
data=spectra[2].data
data
# Out:
# FITS_rec([(-9999.    , -9.9990000e+03, -9999.    , -9999.    , -9.9990000e+03, -9.9990000e+03, -9.999e+03, -9999., -9.99900000e+03, -9.9990000e+03, -9999.      , -9.9990000e+03, -9.99900000e+03, -9999., -9999., -9.9990000e+03, -9.9990000e+03, -9999, 1033.82 , -2.3416111e-09, 0.00657499, -9999., ''),
#           (-9999.    , -9.9990000e+03, -9999.    , -9999.    , -9.9990000e+03, -9.9990000e+03, -9.999e+03, -9999., -9.99900000e+03, -9.9990000e+03, -9999.      , -9.9990000e+03, -9.99900000e+03, -9999., -9999., -9.9990000e+03, -9.9990000e+03, -9999, 1215.67 ,  2.0000000e+00, 0.00657499, -9999., ''),
#           (-9999.    , -9.9990000e+03, -9999.    , -9999.    , -9.9990000e+03, -9.9990000e+03, -9.999e+03, -9999., -9.99900000e+03, -9.9990000e+03, -9999.      , -9.9990000e+03, -9.99900000e+03, -9999., -9999., -9.9990000e+03, -9.9990000e+03, -9999, 1240.81 ,  1.3563156e-19, 0.00657499, -9999., ''),
# ...

# %%
data=spectra[3].data
data
# Out:
# FITS_rec([(0.4289477, 0.00022902, 0.32245266, 2, 0.4827586)],
#          dtype=(numpy.record, [('z', '>f4'), ('zErr', '>f4'), ('conf', '>f4'), ('nFit', '>i4'), ('wtFit', '>f4')]))

# %%
data=spectra[4].data
data
# Out:
# FITS_rec([( 0, 0, -9999.      , -9.9990000e+03, -9.9990000e+03, -9.9990000e+03, -9.99700000e+03, -9.99900000e+03, -9999.     , -9999., -9.9990000e+03, -9.9990000e+03),
#           ( 1, 0, -9999.      , -9.9990000e+03, -9.9990000e+03, -9.9990000e+03, -9.99700000e+03, -9.99900000e+03, -9999.     , -9999., -9.9990000e+03, -9.9990000e+03),
#           ( 2, 0,    14.      , -4.8200982e-03,  2.4573845e-04,  3.6000425e-01,  1.29955239e-03,  1.64076816e-02,   345.1886 , -9999.,  1.0404379e+00,  4.5576356e-02),
#           ( 3, 0,    58.      ,  4.8428187e-03,  1.1203000e-04,  1.9773240e+00,  4.52005938e-02,  8.73304307e-02,   345.1886 , -9999.,  4.7525898e-01,  4.4165969e-02),
#           ( 4, 0,    49.      ,  4.7864481e-03,  9.9566336e-05,  2.4226344e+00,  1.12964384e-01,  1.04617655e-01,   345.1886 , -9999.,  4.1342422e-01,  4.3183427e-02),
# ...

# %%
data=spectra[5].data
data
# Out:
# FITS_rec([('Lick_CN1',  0.10556677, 0.16351055,  3.2789777e-03,  5.0860192e-03, 4143.293, 4178.302, 0.00657499,  35.90995 ),
#           ('Lick_CN2',  1.3849133 , 0.16092011,  4.3823313e-02,  5.1958938e-03, 4143.293, 4178.302, 0.00657499,  35.90995 ),
#           ('Lick_Ca4227',  1.3411851 , 0.08836277,  1.2318923e-01,  8.5936021e-03, 4223.439, 4235.943, 0.00657499,  36.57366 ),
#           ('Lick_G4300',  4.3098893 , 0.1453256 ,  1.4263548e-01,  5.1397406e-03, 4282.58 , 4317.589, 0.00657499,  36.674244),
#           ('Lick_Fe4383',  4.103228  , 0.17576006,  9.0580568e-02,  4.0464024e-03, 4370.353, 4421.616, 0.00657499,  39.790855),
#           ('Lick_Ca4455',  1.2457913 , 0.11603107,  6.1827477e-02,  5.9250398e-03, 4453.375, 4475.881, 0.00657499,  41.110016),
#           ('Lick_Fe4531',  2.959516  , 0.15528214,  7.3841885e-02,  4.0090596e-03, 4515.516, 4560.528, 0.00657499,  42.357597),
# ...

# %%
data=spectra[6].data
data
# Out:
# FITS_rec([(83886080, 83886080, 0.     ), (16777216, 83886080, 0.     ),
#           (16777216, 16777216, 1.10105), ...,
#           (16777216, 16777216, 0.     ), (16777216, 16777216, 0.     ),
#           (16777216, 16777216, 0.     )],
#          dtype=(numpy.record, [('andMask', '>i4'), ('orMask', '>i4'), ('dispersion', '>f4')]))
